# %% [markdown]
# <a href="https://colab.research.google.com/github/JaimeLopezGarrido/Trabajos_Labo1/blob/main/src/ensembles/Tarea_05_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# ---
# # Resumen Hiperparametros
#
# LightGBM utiliza el algoritmo de crecimiento de árbol "leaf-wise" (por hoja), mientras que muchas otras herramientas populares utilizan el crecimiento "depth-wise" (por profundidad).
#
# Parámetros Importantes para el Árbol "Leaf-wise":
#
# - *num_leaves*  = Número máximo de hojas que cada árbol puede tener; controla complejidad.
#
#       Este es el parámetro principal para controlar la complejidad del modelo de árbol. Una profundidad no restringida puede inducir el sobreajuste.$num\_leaves = 2^{(max\_depth)}$ para obtener el mismo número de hojas que un árbol "depth-wise".
#
#       - Tiene que ser menor que 2^{(max\_depth)} para evitar overfitting.
#       - Disminuirlo acelera el entrenamiento y reduce overfitting.
#
# - *min_data_in_leaf* = Número mínimo de observaciones que cada hoja debe contener.
#
#       Muy importante para prevenir overfitting, ya que previene hojas con muy pocos datos. Cientos o miles es suficiente para un conjunto de datos grande.
#       - Si sobreajusta hay que subirlo
#       - Si subajusta hay que bajarlo
#
# - *max_depth* = Profundidad máxima de cada árbol; ≤0 significa sin límite. Disminuirlo reduce tiempo y sobreajuste.
#
#       -1 → sin límite (LightGBM lo decide por num_leaves)
#
#       3–8 → árboles pequeños y conservadores
#
#       8–15 → árboles medianos
#
#       > 15 → árboles muy complejos, riesgo de sobreajuste
#
#
#
# ---
# # Arboles, menos profundos, mas rapidos, pero menos precisos.
#
#
# - Disminuir *max_depth*: Reducir la profundidad máxima del árbol para limitar el crecimiento y el tiempo de entrenamiento.
# - Disminuir *num_leaves*: Reducir el número máximo de nodos hoja por árbol, controlando la complejidad y disminuyendo el tiempo de entrenamiento.
# - Aumentar *min_gain_to_split*: Incrementar la ganancia mínima requerida para una división, evitando divisiones de mejora muy pequeña y acortando el entrenamiento.
# - Aumentar *min_data_in_leaf* y *min_sum_hessian_in_leaf*: Aumentar estos valores para prevenir la creación de nodos de árbol muy específicos (sobreajuste) y reducir el tiempo de entrenamiento.
#
# ---
#
# # Entrenar menos árboles
# *num_iterations*
#
# - Número de árboles o rondas de boosting.
#
# - Valores típicos: 500–2000.
#
# - Menos iteraciones → menos tiempo de entrenamiento.
#
# - Si se reduce num_iterations, conviene subir learning_rate (por ejemplo, de 0.03 a 0.1).
#
# *learning_rate*
#
# - Cuánto se ajusta el modelo en cada iteración.
#
# - Valores típicos: 0.01–0.1.
#
# - No afecta el tiempo de entrenamiento, pero sí la precisión.
#
# *early_stopping_round*
#
# - Detiene el entrenamiento si no mejora tras X iteraciones.
#
# - Ejemplo: early_stopping_round = 50.
#
# - Requiere usar un set de validación.
#
# - Permite ahorrar tiempo sin perder rendimiento.
#
# ---
#
# # Menos divisiones por nodo
# *feature_pre_filter*
#
# Si está en TRUE (por defecto), LightGBM filtra variables con poca información antes de entrenar. Mantenerlo en TRUE para acelerar.
#
# *max_bin*
#
# - Cantidad máxima de bins por variable continua.
#
# - Menor valor = entrenamiento más rápido pero menos preciso.
#
# - Valores típicos: 31–255.
#
# - Reducirlo acorta el tiempo de entrenamiento.
#
# *min_data_in_bin*
#
# - Mínimo de datos por bin.
#
# - Aumentarlo reduce el número de bins y acelera el proceso.
#
# - Valor típico: 3–10.
#
# *feature_fraction*
#
# - Porcentaje de variables usadas en cada árbol.
#
# - Ejemplo: feature_fraction = 0.5 usa el 50% de las variables al azar.
#
# - Reducirlo mejora velocidad y ayuda a evitar sobreajuste.
#
# - Valores típicos: 0.5–0.9.
#
# *max_cat_threshold*
#
# - Número máximo de combinaciones evaluadas para variables categóricas.
#
# - Reducirlo disminuye tiempo de cómputo.
#
# - Valores comunes: 16–64.
#
# ---
#
#
# # Usar menos datos por iteración
# *bagging_fraction* y *bagging_freq*
#
# Permiten usar una muestra aleatoria del dataset en cada iteración.
#
# Ejemplo:
#
# - bagging_fraction = 0.75 → usa el 75% de los datos.
#
# - bagging_freq = 5 → cambia la muestra cada 5 iteraciones.
#
# Reducir bagging_fraction acelera el entrenamiento y puede mejorar generalización.
#
# ---
#
# # Para una Mejor Precisión
#
# Para maximizar la precisión del modelo (generalmente a costa de un mayor tiempo de entrenamiento):
#
# - Usar un max_bin grande (puede ser más lento).
#
# - Usar un learning_rate pequeño con un num_iterations grande.
#
# - Usar un num_leaves grande (puede causar sobreajuste).
#
# - Usar datos de entrenamiento más grandes.
#
# - Probar el booster dart.
#
# **Cómo Lidiar con el Sobreajuste**
#
# Para ayudar al modelo a generalizar mejor y evitar el sobreajuste:
#
# - Usar un max_bin pequeño.
#
# - Usar un num_leaves pequeño.
#
# - Usar min_data_in_leaf y min_sum_hessian_in_leaf.
#
# - Usar bagging (agregación de bootstrap) configurando bagging_fraction y bagging_freq.
#
# - Usar submuestreo de características (feature sub-sampling) configurando feature_fraction.
#
# - Usar datos de entrenamiento más grandes.
#
# - Probar lambda_l1, lambda_l2 y min_gain_to_split para regularización.
#
# - Probar max_depth para evitar el crecimiento de árboles profundos.
#
# - Probar el algoritmo extra_trees.
#
# - Probar aumentar path_smooth.

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Drive already mounted at /content/.drive; to attempt to forcibly remount, call drive.mount("/content/.drive", force_remount=True).

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi
# Out:
# ln: failed to create symbolic link '/content/buckets/b1/labo1': File exists

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 06:11:29 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660381 35.3 1454451    77.7 1454451  77.7
# Vcells 1226627  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()

# %%
PARAM$experimento <- 3
PARAM$semilla_primigenia <- 100007

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
#PARAM$hypeparametertuning$hs <- makeParamSet(
#  makeNumericParam("learning_rate", lower = 0.01, upper = 0.05),
#  makeIntegerParam("num_leaves", lower = 16L, upper = 128L),
#  makeNumericParam("feature_fraction", lower = 0.5, upper = 0.9),
#  makeNumericParam("bagging_fraction", lower = 0.7, upper = 1.0),
#  makeIntegerParam("min_data_in_leaf", lower = 20L, upper = 200L),
#  makeNumericParam("lambda_l1", lower = 0, upper = 10),
#  makeNumericParam("lambda_l2", lower = 0, upper = 10),
#  makeNumericParam("min_gain_to_split", lower = 0, upper = 0.5),
#  makeIntegerParam("max_depth", lower = -1L, upper = 10L)
#)

PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("learning_rate", lower = 0.01, upper = 0.03),
  makeIntegerParam("num_leaves", lower = 32L, upper = 96L),
  makeNumericParam("feature_fraction", lower = 0.6, upper = 0.9),
  makeNumericParam("bagging_fraction", lower = 0.7, upper = 1.0),
  makeIntegerParam("bagging_freq", lower = 0L, upper = 10L),
  makeIntegerParam("min_data_in_leaf", lower = 50L, upper = 250L),
  makeNumericParam("lambda_l1", lower = 0, upper = 10),
  makeNumericParam("lambda_l2", lower = 0, upper = 10),
  makeNumericParam("min_gain_to_split", lower = 0, upper = 0.3),
  makeIntegerParam("max_depth", lower = -1L, upper = 10L),
  makeNumericParam("min_sum_hessian_in_leaf", lower = 0.0001, upper = 10),
  makeNumericParam("scale_pos_weight", lower = 10, upper = 200)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 35 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83029
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Nov 03 06:15:07 PM 2025 AUC 0.924298610564258
#
# Mon Nov 03 06:18:15 PM 2025 AUC 0.919588656864493
#
# Mon Nov 03 06:21:03 PM 2025 AUC 0.925767670869332
#
# Mon Nov 03 06:25:28 PM 2025 AUC 0.926786844965511
#
# Mon Nov 03 06:28:40 PM 2025 AUC 0.926273791954698
#
# Mon Nov 03 06:31:05 PM 2025 AUC 0.923885726450452
#
# Mon Nov 03 06:35:26 PM 2025 AUC 0.922930398089533
#
# Mon Nov 03 06:40:45 PM 2025 AUC 0.923444385775205
#
# Mon Nov 03 06:43:34 PM 2025 AUC 0.9267843831402
#
# Mon Nov 03 06:48:24 PM 2025 AUC 0.928875520763654
#
# Mon Nov 03 06:52:07 PM 2025 AUC 0.92698313647696
#
# Mon Nov 03 06:57:15 PM 2025 AUC 0.927964877360894
#
# Mon Nov 03 07:00:48 PM 2025 AUC 0.924773729170535
#
# Mon Nov 03 07:03:56 PM 2025 AUC 0.924799457837154
#
# Mon Nov 03 07:05:49 PM 2025 AUC 0.919362297094406
#
# Mon Nov 03 07:09:02 PM 2025 AUC 0.926037891588191
#
# Mon Nov 03 07:10:41 PM 2025 AUC 0.918602655924075
#
# Mon Nov 03 07:13:24 PM 2025 AUC 0.920872497213841
#
# Mon Nov 03 07:19:00 PM 2025 AUC 0.927833593087883
#
# Mon Nov 03 07:21:29 PM 2025 AUC 0.922933080065878
#
# Mon Nov 03 07:27:36 PM 2025 AUC 0.926464191053726
#
# Mon Nov 03 07:31:28 PM 2025 AUC 0.926495757649017
#
# Mon Nov 03 07:37:18 PM 2025 AUC 0.924544599656414
#
# Mon Nov 03 07:41:51 PM 2025 AUC 0.928202862228913
#
# Mon Nov 03 07:48:07 PM 2025 AUC 0.929133243449963
#
# Mon Nov 03 07:54:01 PM 2025 AUC 0.927898214075873
#
# Mon Nov 03 07:57:57 PM 2025 AUC 0.926560234236058
#
# Mon Nov 03 08:04:46 PM 2025 AUC 0.9291766603647
#
# Mon Nov 03 08:08:42 PM 2025 AUC 0.926884974269208
#
# Mon Nov 03 08:13:40 PM 2025 AUC 0.925575769788573
#
# Mon Nov 03 08:18:49 PM 2025 AUC 0.927841596670139
#
# Mon Nov 03 08:23:41 PM 2025 AUC 0.926858047917558
#
# Mon Nov 03 08:29:47 PM 2025 AUC 0.926269209929417
#
# Mon Nov 03 08:34:44 PM 2025 AUC 0.92838383739757
#
# Mon Nov 03 08:39:57 PM 2025 AUC 0.928428630174132
#
# Mon Nov 03 08:43:51 PM 2025 AUC 0.92437272323978
#
# Mon Nov 03 08:47:59 PM 2025 AUC 0.929127521511209
#
# Mon Nov 03 08:54:29 PM 2025 AUC 0.929180887742746
#
# Mon Nov 03 09:01:39 PM 2025 AUC 0.929354389214288
#
# Mon Nov 03 09:08:31 PM 2025 AUC 0.928690192787064
#
# Mon Nov 03 09:12:31 PM 2025 AUC 0.923626013786553
#
# Mon Nov 03 09:16:07 PM 2025 AUC 0.927811686872322
#
# Mon Nov 03 09:21:04 PM 2025 AUC 0.926552943032721
#
# Mon Nov 03 09:26:05 PM 2025 AUC 0.927244960884603
#
# Mon Nov 03 09:30:12 PM 2025 AUC 0.922142444063616
#
# Mon Nov 03 09:34:52 PM 2025 AUC 0.929232090109057
#
# Mon Nov 03 09:38:28 PM 2025 AUC 0.921521148606209
#
# Mon Nov 03 09:42:54 PM 2025 AUC 0.926619361042894
#
# [mbo] 0: learning_rate=0.0183; num_leaves=90; feature_fraction=0.687; bagging_fraction=0.919; bagging_freq=4; min_data_in_leaf=229; lambda_l1=1.4; lambda_l2=6.82; min_gain_to_split=0.229; max_depth=2; min_sum_hessian_in_leaf=0.942; scale_pos_weight=124 : y = 0.924 : 178.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0188; num_leaves=48; feature_fraction=0.731; bagging_fraction=0.771; bagging_freq=2; min_data_in_leaf=110; lambda_l1=2.23; lambda_l2=3.58; min_gain_to_split=0.0651; max_depth=1; min_sum_hessian_in_leaf=6.07; scale_pos_weight=40.3 : y = 0.92 : 188.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0208; num_leaves=75; feature_fraction=0.808; bagging_fraction=0.807; bagging_freq=6; min_data_in_leaf=107; lambda_l1=9.24; lambda_l2=3.15; min_gain_to_split=0.211; max_depth=3; min_sum_hessian_in_leaf=4.08; scale_pos_weight=113 : y = 0.926 : 167.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0177; num_leaves=42; feature_fraction=0.696; bagging_fraction=0.894; bagging_freq=5; min_data_in_leaf=199; lambda_l1=3.4; lambda_l2=5.73; min_gain_to_split=0.0218; max_depth=6; min_sum_hessian_in_leaf=4.9; scale_pos_weight=85.5 : y = 0.927 : 264.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0192; num_leaves=45; feature_fraction=0.765; bagging_fraction=0.862; bagging_freq=4; min_data_in_leaf=93; lambda_l1=3.62; lambda_l2=7.32; min_gain_to_split=0.252; max_depth=3; min_sum_hessian_in_leaf=7.85; scale_pos_weight=100 : y = 0.926 : 192.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0256; num_leaves=65; feature_fraction=0.788; bagging_fraction=0.784; bagging_freq=6; min_data_in_leaf=173; lambda_l1=1.06; lambda_l2=5.36; min_gain_to_split=0.166; max_depth=2; min_sum_hessian_in_leaf=6.64; scale_pos_weight=148 : y = 0.924 : 145.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0116; num_leaves=83; feature_fraction=0.756; bagging_fraction=0.753; bagging_freq=9; min_data_in_leaf=84; lambda_l1=1.49; lambda_l2=3.4; min_gain_to_split=0.0753; max_depth=7; min_sum_hessian_in_leaf=7.95; scale_pos_weight=188 : y = 0.923 : 260.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0232; num_leaves=45; feature_fraction=0.759; bagging_fraction=0.968; bagging_freq=2; min_data_in_leaf=88; lambda_l1=8.15; lambda_l2=8.08; min_gain_to_split=0.0709; max_depth=5; min_sum_hessian_in_leaf=3.63; scale_pos_weight=158 : y = 0.923 : 319.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0119; num_leaves=81; feature_fraction=0.731; bagging_fraction=0.745; bagging_freq=10; min_data_in_leaf=242; lambda_l1=4.12; lambda_l2=5.01; min_gain_to_split=0.0389; max_depth=4; min_sum_hessian_in_leaf=4.4; scale_pos_weight=51 : y = 0.927 : 169.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0217; num_leaves=50; feature_fraction=0.77; bagging_fraction=0.82; bagging_freq=9; min_data_in_leaf=53; lambda_l1=3.91; lambda_l2=8.73; min_gain_to_split=0.0835; max_depth=8; min_sum_hessian_in_leaf=1.42; scale_pos_weight=15.2 : y = 0.929 : 290.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0125; num_leaves=73; feature_fraction=0.717; bagging_fraction=0.796; bagging_freq=5; min_data_in_leaf=187; lambda_l1=0.698; lambda_l2=4.18; min_gain_to_split=0.205; max_depth=5; min_sum_hessian_in_leaf=4.67; scale_pos_weight=95.2 : y = 0.927 : 222.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0239; num_leaves=39; feature_fraction=0.78; bagging_fraction=0.931; bagging_freq=6; min_data_in_leaf=178; lambda_l1=2.78; lambda_l2=6.33; min_gain_to_split=0.242; max_depth=0; min_sum_hessian_in_leaf=1.05; scale_pos_weight=81 : y = 0.928 : 308.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0278; num_leaves=93; feature_fraction=0.632; bagging_fraction=0.879; bagging_freq=4; min_data_in_leaf=162; lambda_l1=5.43; lambda_l2=3.99; min_gain_to_split=0.145; max_depth=3; min_sum_hessian_in_leaf=1.6; scale_pos_weight=173 : y = 0.925 : 212.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.015; num_leaves=87; feature_fraction=0.655; bagging_fraction=0.828; bagging_freq=10; min_data_in_leaf=80; lambda_l1=6.27; lambda_l2=2.79; min_gain_to_split=0.291; max_depth=4; min_sum_hessian_in_leaf=7.03; scale_pos_weight=169 : y = 0.925 : 187.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0211; num_leaves=64; feature_fraction=0.645; bagging_fraction=0.883; bagging_freq=0; min_data_in_leaf=158; lambda_l1=6.23; lambda_l2=9.72; min_gain_to_split=0.194; max_depth=1; min_sum_hessian_in_leaf=5.78; scale_pos_weight=83.7 : y = 0.919 : 113.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0166; num_leaves=95; feature_fraction=0.9; bagging_fraction=0.953; bagging_freq=10; min_data_in_leaf=194; lambda_l1=0.972; lambda_l2=4.87; min_gain_to_split=0.245; max_depth=4; min_sum_hessian_in_leaf=4.27; scale_pos_weight=114 : y = 0.926 : 193.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0223; num_leaves=54; feature_fraction=0.711; bagging_fraction=0.816; bagging_freq=0; min_data_in_leaf=190; lambda_l1=5.75; lambda_l2=1.53; min_gain_to_split=0.0623; max_depth=1; min_sum_hessian_in_leaf=9.39; scale_pos_weight=138 : y = 0.919 : 98.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0187; num_leaves=85; feature_fraction=0.886; bagging_fraction=0.838; bagging_freq=3; min_data_in_leaf=163; lambda_l1=9.4; lambda_l2=4.55; min_gain_to_split=0.141; max_depth=1; min_sum_hessian_in_leaf=3.37; scale_pos_weight=29.6 : y = 0.921 : 162.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0294; num_leaves=57; feature_fraction=0.856; bagging_fraction=0.867; bagging_freq=7; min_data_in_leaf=142; lambda_l1=9.91; lambda_l2=1.09; min_gain_to_split=0.125; max_depth=0; min_sum_hessian_in_leaf=5.3; scale_pos_weight=131 : y = 0.928 : 336.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0125; num_leaves=37; feature_fraction=0.615; bagging_fraction=0.917; bagging_freq=1; min_data_in_leaf=68; lambda_l1=7.11; lambda_l2=2.31; min_gain_to_split=0.27; max_depth=2; min_sum_hessian_in_leaf=7.37; scale_pos_weight=106 : y = 0.923 : 149.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0105; num_leaves=48; feature_fraction=0.67; bagging_fraction=0.941; bagging_freq=3; min_data_in_leaf=128; lambda_l1=4.57; lambda_l2=9.92; min_gain_to_split=0.199; max_depth=9; min_sum_hessian_in_leaf=5.14; scale_pos_weight=168 : y = 0.926 : 367.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.02; num_leaves=67; feature_fraction=0.627; bagging_fraction=0.995; bagging_freq=7; min_data_in_leaf=64; lambda_l1=8.64; lambda_l2=6.52; min_gain_to_split=0.0936; max_depth=4; min_sum_hessian_in_leaf=0.312; scale_pos_weight=68.4 : y = 0.926 : 231.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0267; num_leaves=71; feature_fraction=0.84; bagging_fraction=0.948; bagging_freq=8; min_data_in_leaf=150; lambda_l1=1.79; lambda_l2=0.438; min_gain_to_split=0.0481; max_depth=10; min_sum_hessian_in_leaf=2.66; scale_pos_weight=119 : y = 0.925 : 350.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0259; num_leaves=35; feature_fraction=0.816; bagging_fraction=0.713; bagging_freq=5; min_data_in_leaf=212; lambda_l1=9.77; lambda_l2=4.78; min_gain_to_split=0.175; max_depth=10; min_sum_hessian_in_leaf=8.56; scale_pos_weight=199 : y = 0.928 : 272.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0174; num_leaves=80; feature_fraction=0.797; bagging_fraction=0.788; bagging_freq=5; min_data_in_leaf=56; lambda_l1=4.94; lambda_l2=9.52; min_gain_to_split=0.236; max_depth=-1; min_sum_hessian_in_leaf=9.96; scale_pos_weight=89.2 : y = 0.929 : 376.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0227; num_leaves=57; feature_fraction=0.786; bagging_fraction=0.804; bagging_freq=3; min_data_in_leaf=222; lambda_l1=3.28; lambda_l2=0.262; min_gain_to_split=0.159; max_depth=10; min_sum_hessian_in_leaf=0.0268; scale_pos_weight=45.6 : y = 0.928 : 353.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0142; num_leaves=43; feature_fraction=0.893; bagging_fraction=0.912; bagging_freq=1; min_data_in_leaf=140; lambda_l1=5.9; lambda_l2=7.87; min_gain_to_split=0.133; max_depth=8; min_sum_hessian_in_leaf=9.73; scale_pos_weight=75.4 : y = 0.927 : 236.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0159; num_leaves=55; feature_fraction=0.821; bagging_fraction=0.844; bagging_freq=2; min_data_in_leaf=58; lambda_l1=0.623; lambda_l2=5.6; min_gain_to_split=0.114; max_depth=-1; min_sum_hessian_in_leaf=3.89; scale_pos_weight=35.2 : y = 0.929 : 408.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0272; num_leaves=52; feature_fraction=0.742; bagging_fraction=0.763; bagging_freq=9; min_data_in_leaf=208; lambda_l1=7.64; lambda_l2=9.27; min_gain_to_split=0.0349; max_depth=6; min_sum_hessian_in_leaf=5.87; scale_pos_weight=59.8 : y = 0.927 : 236.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0234; num_leaves=61; feature_fraction=0.603; bagging_fraction=0.7; bagging_freq=0; min_data_in_leaf=134; lambda_l1=5.15; lambda_l2=1.27; min_gain_to_split=0.103; max_depth=10; min_sum_hessian_in_leaf=2.14; scale_pos_weight=149 : y = 0.926 : 297.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0169; num_leaves=75; feature_fraction=0.858; bagging_fraction=0.721; bagging_freq=7; min_data_in_leaf=120; lambda_l1=5.32; lambda_l2=2.09; min_gain_to_split=0.219; max_depth=9; min_sum_hessian_in_leaf=8.4; scale_pos_weight=23.8 : y = 0.928 : 309.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0288; num_leaves=69; feature_fraction=0.869; bagging_fraction=0.972; bagging_freq=9; min_data_in_leaf=202; lambda_l1=6.59; lambda_l2=6.13; min_gain_to_split=0.294; max_depth=7; min_sum_hessian_in_leaf=1.77; scale_pos_weight=65.2 : y = 0.927 : 291.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0138; num_leaves=62; feature_fraction=0.827; bagging_fraction=0.962; bagging_freq=8; min_data_in_leaf=102; lambda_l1=2.37; lambda_l2=0.156; min_gain_to_split=0.278; max_depth=-1; min_sum_hessian_in_leaf=3.15; scale_pos_weight=179 : y = 0.926 : 365.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0253; num_leaves=83; feature_fraction=0.609; bagging_fraction=0.856; bagging_freq=1; min_data_in_leaf=216; lambda_l1=6.72; lambda_l2=9.05; min_gain_to_split=0.0278; max_depth=9; min_sum_hessian_in_leaf=8.3; scale_pos_weight=72.4 : y = 0.928 : 297.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0109; num_leaves=78; feature_fraction=0.702; bagging_fraction=0.73; bagging_freq=0; min_data_in_leaf=113; lambda_l1=7; lambda_l2=1.99; min_gain_to_split=0.187; max_depth=-1; min_sum_hessian_in_leaf=2.98; scale_pos_weight=184 : y = 0.928 : 312.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0214; num_leaves=69; feature_fraction=0.679; bagging_fraction=0.99; bagging_freq=8; min_data_in_leaf=100; lambda_l1=7.9; lambda_l2=3.84; min_gain_to_split=0.11; max_depth=5; min_sum_hessian_in_leaf=9.08; scale_pos_weight=192 : y = 0.924 : 233.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0149; num_leaves=32; feature_fraction=0.661; bagging_fraction=0.929; bagging_freq=9; min_data_in_leaf=152; lambda_l1=2.7; lambda_l2=7.09; min_gain_to_split=0.217; max_depth=6; min_sum_hessian_in_leaf=8.95; scale_pos_weight=20.8 : y = 0.929 : 248.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0197; num_leaves=87; feature_fraction=0.75; bagging_fraction=0.836; bagging_freq=8; min_data_in_leaf=169; lambda_l1=2.98; lambda_l2=7.06; min_gain_to_split=0.017; max_depth=0; min_sum_hessian_in_leaf=2.71; scale_pos_weight=126 : y = 0.929 : 389.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0287; num_leaves=59; feature_fraction=0.881; bagging_fraction=0.979; bagging_freq=2; min_data_in_leaf=247; lambda_l1=4.62; lambda_l2=0.961; min_gain_to_split=0.00098; max_depth=9; min_sum_hessian_in_leaf=5.48; scale_pos_weight=12 : y = 0.929 : 430.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0156; num_leaves=77; feature_fraction=0.87; bagging_fraction=0.904; bagging_freq=5; min_data_in_leaf=232; lambda_l1=9.16; lambda_l2=5.92; min_gain_to_split=0.259; max_depth=0; min_sum_hessian_in_leaf=9.34; scale_pos_weight=136 : y = 0.929 : 412.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0266; num_leaves=66; feature_fraction=0.69; bagging_fraction=0.74; bagging_freq=7; min_data_in_leaf=75; lambda_l1=4.17; lambda_l2=8.44; min_gain_to_split=0.284; max_depth=6; min_sum_hessian_in_leaf=2.3; scale_pos_weight=103 : y = 0.924 : 239.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.03; num_leaves=89; feature_fraction=0.803; bagging_fraction=0.71; bagging_freq=1; min_data_in_leaf=234; lambda_l1=8.75; lambda_l2=7.57; min_gain_to_split=0.18; max_depth=7; min_sum_hessian_in_leaf=2; scale_pos_weight=47.4 : y = 0.928 : 216.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0137; num_leaves=95; feature_fraction=0.623; bagging_fraction=0.733; bagging_freq=10; min_data_in_leaf=180; lambda_l1=8.45; lambda_l2=0.828; min_gain_to_split=0.097; max_depth=8; min_sum_hessian_in_leaf=6.83; scale_pos_weight=154 : y = 0.927 : 296.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0247; num_leaves=37; feature_fraction=0.724; bagging_fraction=0.873; bagging_freq=4; min_data_in_leaf=243; lambda_l1=0.194; lambda_l2=8.31; min_gain_to_split=0.121; max_depth=8; min_sum_hessian_in_leaf=0.536; scale_pos_weight=162 : y = 0.927 : 301.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0281; num_leaves=52; feature_fraction=0.834; bagging_fraction=0.76; bagging_freq=3; min_data_in_leaf=77; lambda_l1=0.363; lambda_l2=1.71; min_gain_to_split=0.052; max_depth=5; min_sum_hessian_in_leaf=7.62; scale_pos_weight=190 : y = 0.922 : 247.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0132; num_leaves=34; feature_fraction=0.849; bagging_fraction=0.893; bagging_freq=6; min_data_in_leaf=122; lambda_l1=7.93; lambda_l2=2.5; min_gain_to_split=0.153; max_depth=7; min_sum_hessian_in_leaf=0.638; scale_pos_weight=30.7 : y = 0.929 : 280.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0102; num_leaves=41; feature_fraction=0.641; bagging_fraction=0.777; bagging_freq=2; min_data_in_leaf=221; lambda_l1=7.48; lambda_l2=8.92; min_gain_to_split=0.0103; max_depth=2; min_sum_hessian_in_leaf=7.1; scale_pos_weight=144 : y = 0.922 : 215.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0245; num_leaves=91; feature_fraction=0.667; bagging_fraction=0.984; bagging_freq=2; min_data_in_leaf=130; lambda_l1=2.04; lambda_l2=3.1; min_gain_to_split=0.264; max_depth=3; min_sum_hessian_in_leaf=6.36; scale_pos_weight=57.4 : y = 0.927 : 266.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Nov 03 09:49:39 PM 2025 AUC 0.929331729925974
#
# [mbo] 1: learning_rate=0.0202; num_leaves=89; feature_fraction=0.753; bagging_fraction=0.761; bagging_freq=3; min_data_in_leaf=179; lambda_l1=4.76; lambda_l2=7.38; min_gain_to_split=0.0513; max_depth=-1; min_sum_hessian_in_leaf=3.97; scale_pos_weight=82.8 : y = 0.929 : 402.8 secs : infill_ei
#
# Mon Nov 03 09:54:38 PM 2025 AUC 0.929691068412012
#
# [mbo] 2: learning_rate=0.0155; num_leaves=74; feature_fraction=0.675; bagging_fraction=0.721; bagging_freq=0; min_data_in_leaf=89; lambda_l1=7.11; lambda_l2=3.4; min_gain_to_split=0.132; max_depth=-1; min_sum_hessian_in_leaf=7.29; scale_pos_weight=56.4 : y = 0.93 : 298.2 secs : infill_ei
#
# Saved the current state after iteration 3 in the file bayesiana.RDATA.
#
# Mon Nov 03 09:59:42 PM 2025 AUC 0.929133823126489
#
# [mbo] 3: learning_rate=0.0122; num_leaves=71; feature_fraction=0.765; bagging_fraction=0.759; bagging_freq=0; min_data_in_leaf=82; lambda_l1=9.67; lambda_l2=8.62; min_gain_to_split=0.13; max_depth=-1; min_sum_hessian_in_leaf=2.58; scale_pos_weight=64.9 : y = 0.929 : 302.1 secs : infill_ei
#
# Mon Nov 03 10:04:27 PM 2025 AUC 0.929093133608903
#
# [mbo] 4: learning_rate=0.0201; num_leaves=68; feature_fraction=0.696; bagging_fraction=0.709; bagging_freq=0; min_data_in_leaf=132; lambda_l1=2.12; lambda_l2=7.43; min_gain_to_split=0.226; max_depth=-1; min_sum_hessian_in_leaf=6.62; scale_pos_weight=57.6 : y = 0.929 : 284.0 secs : infill_ei
#
# Mon Nov 03 10:09:15 PM 2025 AUC 0.929236720806086
#
# [mbo] 5: learning_rate=0.011; num_leaves=82; feature_fraction=0.841; bagging_fraction=0.711; bagging_freq=1; min_data_in_leaf=106; lambda_l1=5.61; lambda_l2=4.83; min_gain_to_split=0.0516; max_depth=-1; min_sum_hessian_in_leaf=8.82; scale_pos_weight=68 : y = 0.929 : 286.9 secs : infill_ei
#
# Saved the current state after iteration 6 in the file bayesiana.RDATA.
#
# Mon Nov 03 10:14:08 PM 2025 AUC 0.928094798377873
#
# [mbo] 6: learning_rate=0.0244; num_leaves=83; feature_fraction=0.658; bagging_fraction=0.779; bagging_freq=1; min_data_in_leaf=50; lambda_l1=5.45; lambda_l2=5.83; min_gain_to_split=0.0447; max_depth=-1; min_sum_hessian_in_leaf=6.8; scale_pos_weight=96.6 : y = 0.928 : 290.7 secs : infill_ei
#
# Mon Nov 03 10:20:10 PM 2025 AUC 0.929516224861415
#
# [mbo] 7: learning_rate=0.013; num_leaves=81; feature_fraction=0.683; bagging_fraction=0.759; bagging_freq=6; min_data_in_leaf=160; lambda_l1=7.06; lambda_l2=5.48; min_gain_to_split=0.141; max_depth=-1; min_sum_hessian_in_leaf=6.14; scale_pos_weight=11.1 : y = 0.93 : 361.3 secs : infill_ei
#
# Saved the current state after iteration 8 in the file bayesiana.RDATA.
#
# Mon Nov 03 10:26:47 PM 2025 AUC 0.929476780156701
#
# [mbo] 8: learning_rate=0.0178; num_leaves=77; feature_fraction=0.834; bagging_fraction=0.776; bagging_freq=3; min_data_in_leaf=157; lambda_l1=7.34; lambda_l2=4.05; min_gain_to_split=0.187; max_depth=-1; min_sum_hessian_in_leaf=9.06; scale_pos_weight=30.6 : y = 0.929 : 396.1 secs : infill_ei
#
# Mon Nov 03 10:32:09 PM 2025 AUC 0.929419041400929
#
# [mbo] 9: learning_rate=0.0144; num_leaves=78; feature_fraction=0.713; bagging_fraction=0.803; bagging_freq=0; min_data_in_leaf=187; lambda_l1=4.78; lambda_l2=7.77; min_gain_to_split=0.143; max_depth=-1; min_sum_hessian_in_leaf=8.81; scale_pos_weight=36.6 : y = 0.929 : 320.4 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana.RDATA.
#
# Mon Nov 03 10:37:57 PM 2025 AUC 0.929336006572737
#
# [mbo] 10: learning_rate=0.0116; num_leaves=53; feature_fraction=0.707; bagging_fraction=0.725; bagging_freq=3; min_data_in_leaf=183; lambda_l1=7.3; lambda_l2=3.05; min_gain_to_split=0.196; max_depth=-1; min_sum_hessian_in_leaf=5.41; scale_pos_weight=63.1 : y = 0.929 : 347.1 secs : infill_ei
#
# Mon Nov 03 10:43:14 PM 2025 AUC 0.930138211089672
#
# [mbo] 11: learning_rate=0.0267; num_leaves=36; feature_fraction=0.793; bagging_fraction=0.771; bagging_freq=3; min_data_in_leaf=240; lambda_l1=8.07; lambda_l2=6.83; min_gain_to_split=0.0503; max_depth=9; min_sum_hessian_in_leaf=1.36; scale_pos_weight=10.7 : y = 0.93 : 315.5 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Mon Nov 03 10:47:50 PM 2025 AUC 0.929104390350015
#
# [mbo] 12: learning_rate=0.0299; num_leaves=38; feature_fraction=0.813; bagging_fraction=0.741; bagging_freq=7; min_data_in_leaf=249; lambda_l1=5.18; lambda_l2=4.88; min_gain_to_split=0.0602; max_depth=9; min_sum_hessian_in_leaf=2.76; scale_pos_weight=19.9 : y = 0.929 : 274.4 secs : infill_ei
#
# Mon Nov 03 10:52:03 PM 2025 AUC 0.930231590300131
#
# [mbo] 13: learning_rate=0.027; num_leaves=48; feature_fraction=0.848; bagging_fraction=0.885; bagging_freq=0; min_data_in_leaf=218; lambda_l1=9.85; lambda_l2=6.05; min_gain_to_split=0.0141; max_depth=9; min_sum_hessian_in_leaf=0.578; scale_pos_weight=13 : y = 0.93 : 252.6 secs : infill_ei
#
# Mon Nov 03 10:55:41 PM 2025 AUC 0.929840390892889
#
# [mbo] 14: learning_rate=0.0256; num_leaves=32; feature_fraction=0.74; bagging_fraction=0.849; bagging_freq=0; min_data_in_leaf=146; lambda_l1=8.56; lambda_l2=2.24; min_gain_to_split=0.0592; max_depth=9; min_sum_hessian_in_leaf=4.56; scale_pos_weight=11.8 : y = 0.93 : 217.0 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana.RDATA.
#
# Mon Nov 03 10:59:38 PM 2025 AUC 0.930499430161914
#
# [mbo] 15: learning_rate=0.0231; num_leaves=38; feature_fraction=0.878; bagging_fraction=0.862; bagging_freq=1; min_data_in_leaf=202; lambda_l1=8.43; lambda_l2=3.87; min_gain_to_split=0.0441; max_depth=9; min_sum_hessian_in_leaf=0.681; scale_pos_weight=11.8 : y = 0.93 : 236.2 secs : infill_ei
#
# Mon Nov 03 11:05:41 PM 2025 AUC 0.929954019212704
#
# [mbo] 16: learning_rate=0.0186; num_leaves=44; feature_fraction=0.825; bagging_fraction=0.897; bagging_freq=3; min_data_in_leaf=210; lambda_l1=9.88; lambda_l2=2.95; min_gain_to_split=0.0239; max_depth=9; min_sum_hessian_in_leaf=1.93; scale_pos_weight=10.7 : y = 0.93 : 361.6 secs : infill_ei
#
# Mon Nov 03 11:09:29 PM 2025 AUC 0.928355806858136
#
# [mbo] 17: learning_rate=0.0246; num_leaves=36; feature_fraction=0.865; bagging_fraction=0.781; bagging_freq=0; min_data_in_leaf=247; lambda_l1=9.97; lambda_l2=3.16; min_gain_to_split=0.0957; max_depth=9; min_sum_hessian_in_leaf=3.55; scale_pos_weight=48.5 : y = 0.928 : 226.4 secs : infill_ei
#
# Saved the current state after iteration 18 in the file bayesiana.RDATA.
#
# Mon Nov 03 11:15:47 PM 2025 AUC 0.929306545656999
#
# [mbo] 18: learning_rate=0.0224; num_leaves=60; feature_fraction=0.884; bagging_fraction=0.843; bagging_freq=3; min_data_in_leaf=175; lambda_l1=5.12; lambda_l2=7.86; min_gain_to_split=0.0259; max_depth=9; min_sum_hessian_in_leaf=0.29; scale_pos_weight=10.1 : y = 0.929 : 376.4 secs : infill_ei
#
# Mon Nov 03 11:19:57 PM 2025 AUC 0.930295769020406
#
# [mbo] 19: learning_rate=0.0256; num_leaves=51; feature_fraction=0.737; bagging_fraction=0.954; bagging_freq=0; min_data_in_leaf=244; lambda_l1=6.58; lambda_l2=4.03; min_gain_to_split=0.128; max_depth=9; min_sum_hessian_in_leaf=0.577; scale_pos_weight=10.4 : y = 0.93 : 248.9 secs : infill_ei
#
# Saved the current state after iteration 20 in the file bayesiana.RDATA.
#
# Mon Nov 03 11:27:07 PM 2025 AUC 0.928666069088985
#
# [mbo] 20: learning_rate=0.0146; num_leaves=96; feature_fraction=0.664; bagging_fraction=0.841; bagging_freq=4; min_data_in_leaf=173; lambda_l1=1.86; lambda_l2=9.73; min_gain_to_split=0.235; max_depth=0; min_sum_hessian_in_leaf=3.65; scale_pos_weight=185 : y = 0.929 : 429.2 secs : infill_ei
#
# Mon Nov 03 11:34:03 PM 2025 AUC 0.930175254337141
#
# [mbo] 21: learning_rate=0.0263; num_leaves=63; feature_fraction=0.717; bagging_fraction=0.967; bagging_freq=2; min_data_in_leaf=195; lambda_l1=8.42; lambda_l2=1.54; min_gain_to_split=0.112; max_depth=8; min_sum_hessian_in_leaf=0.418; scale_pos_weight=11.3 : y = 0.93 : 414.1 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Mon Nov 03 11:40:27 PM 2025 AUC 0.928896384842969
#
# [mbo] 22: learning_rate=0.0229; num_leaves=41; feature_fraction=0.628; bagging_fraction=0.855; bagging_freq=2; min_data_in_leaf=239; lambda_l1=5.57; lambda_l2=4.82; min_gain_to_split=0.0303; max_depth=8; min_sum_hessian_in_leaf=0.0998; scale_pos_weight=10.2 : y = 0.929 : 383.1 secs : infill_ei
#
# Mon Nov 03 11:47:32 PM 2025 AUC 0.9302788866234
#
# [mbo] 23: learning_rate=0.0294; num_leaves=74; feature_fraction=0.671; bagging_fraction=0.985; bagging_freq=2; min_data_in_leaf=58; lambda_l1=9.81; lambda_l2=8.31; min_gain_to_split=0.0902; max_depth=8; min_sum_hessian_in_leaf=0.534; scale_pos_weight=10.1 : y = 0.93 : 423.2 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana.RDATA.
#
# Mon Nov 03 11:51:17 PM 2025 AUC 0.92929382805166
#
# [mbo] 24: learning_rate=0.023; num_leaves=35; feature_fraction=0.696; bagging_fraction=0.832; bagging_freq=1; min_data_in_leaf=182; lambda_l1=5.26; lambda_l2=0.774; min_gain_to_split=0.00315; max_depth=9; min_sum_hessian_in_leaf=0.559; scale_pos_weight=11 : y = 0.929 : 224.1 secs : infill_ei
#
# Mon Nov 03 11:57:02 PM 2025 AUC 0.929752519312222
#
# [mbo] 25: learning_rate=0.029; num_leaves=49; feature_fraction=0.738; bagging_fraction=0.985; bagging_freq=3; min_data_in_leaf=74; lambda_l1=9.16; lambda_l2=6.37; min_gain_to_split=0.244; max_depth=8; min_sum_hessian_in_leaf=0.0975; scale_pos_weight=10.3 : y = 0.93 : 343.5 secs : infill_ei
#
# Tue Nov 04 12:02:16 AM 2025 AUC 0.928815177851385
#
# [mbo] 26: learning_rate=0.0295; num_leaves=38; feature_fraction=0.831; bagging_fraction=0.999; bagging_freq=6; min_data_in_leaf=171; lambda_l1=9.25; lambda_l2=5.49; min_gain_to_split=0.074; max_depth=9; min_sum_hessian_in_leaf=0.292; scale_pos_weight=39.5 : y = 0.929 : 312.9 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Tue Nov 04 12:09:22 AM 2025 AUC 0.928316411660896
#
# [mbo] 27: learning_rate=0.0294; num_leaves=89; feature_fraction=0.828; bagging_fraction=0.971; bagging_freq=2; min_data_in_leaf=99; lambda_l1=4.6; lambda_l2=2.46; min_gain_to_split=0.0852; max_depth=8; min_sum_hessian_in_leaf=0.0779; scale_pos_weight=10.4 : y = 0.928 : 424.6 secs : infill_ei
#
# Tue Nov 04 12:15:16 AM 2025 AUC 0.929223199137414
#
# [mbo] 28: learning_rate=0.0294; num_leaves=63; feature_fraction=0.637; bagging_fraction=0.938; bagging_freq=6; min_data_in_leaf=131; lambda_l1=9.73; lambda_l2=7.22; min_gain_to_split=0.092; max_depth=8; min_sum_hessian_in_leaf=5.02; scale_pos_weight=10.3 : y = 0.929 : 351.8 secs : infill_ei
#
# Saved the current state after iteration 29 in the file bayesiana.RDATA.
#
# Tue Nov 04 12:22:04 AM 2025 AUC 0.930043635533806
#
# [mbo] 29: learning_rate=0.0126; num_leaves=83; feature_fraction=0.682; bagging_fraction=0.889; bagging_freq=2; min_data_in_leaf=194; lambda_l1=9.94; lambda_l2=7.98; min_gain_to_split=0.105; max_depth=8; min_sum_hessian_in_leaf=0.224; scale_pos_weight=10.1 : y = 0.93 : 406.7 secs : infill_ei
#
# Tue Nov 04 12:27:23 AM 2025 AUC 0.930713270235202
#
# [mbo] 30: learning_rate=0.012; num_leaves=38; feature_fraction=0.644; bagging_fraction=0.987; bagging_freq=5; min_data_in_leaf=163; lambda_l1=8.19; lambda_l2=8.86; min_gain_to_split=0.0936; max_depth=7; min_sum_hessian_in_leaf=1.17; scale_pos_weight=10.3 : y = 0.931 : 317.0 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Tue Nov 04 12:31:18 AM 2025 AUC 0.93079689234734
#
# [mbo] 31: learning_rate=0.0159; num_leaves=54; feature_fraction=0.663; bagging_fraction=0.984; bagging_freq=1; min_data_in_leaf=208; lambda_l1=9.79; lambda_l2=4.34; min_gain_to_split=0.0749; max_depth=7; min_sum_hessian_in_leaf=0.122; scale_pos_weight=11.2 : y = 0.931 : 233.5 secs : infill_ei
#
# Tue Nov 04 12:35:42 AM 2025 AUC 0.930272419146128
#
# [mbo] 32: learning_rate=0.0144; num_leaves=47; feature_fraction=0.608; bagging_fraction=0.917; bagging_freq=1; min_data_in_leaf=200; lambda_l1=9.73; lambda_l2=8.3; min_gain_to_split=0.187; max_depth=7; min_sum_hessian_in_leaf=0.207; scale_pos_weight=10.3 : y = 0.93 : 262.0 secs : infill_ei
#
# Tue Nov 04 12:39:28 AM 2025 AUC 0.929481440050493
#
# [mbo] 33: learning_rate=0.0136; num_leaves=35; feature_fraction=0.867; bagging_fraction=0.999; bagging_freq=1; min_data_in_leaf=191; lambda_l1=9.16; lambda_l2=8.48; min_gain_to_split=0.0354; max_depth=7; min_sum_hessian_in_leaf=0.862; scale_pos_weight=10 : y = 0.929 : 223.4 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Tue Nov 04 12:44:16 AM 2025 AUC 0.930404545006379
#
# [mbo] 34: learning_rate=0.0136; num_leaves=49; feature_fraction=0.653; bagging_fraction=0.92; bagging_freq=7; min_data_in_leaf=243; lambda_l1=3.55; lambda_l2=2.92; min_gain_to_split=0.11; max_depth=7; min_sum_hessian_in_leaf=1.12; scale_pos_weight=10.2 : y = 0.93 : 286.2 secs : infill_ei
#
# Tue Nov 04 12:48:30 AM 2025 AUC 0.929947954928165
#
# [mbo] 35: learning_rate=0.0114; num_leaves=38; feature_fraction=0.613; bagging_fraction=0.962; bagging_freq=1; min_data_in_leaf=112; lambda_l1=3.79; lambda_l2=1.4; min_gain_to_split=0.0258; max_depth=7; min_sum_hessian_in_leaf=1.2; scale_pos_weight=10.4 : y = 0.93 : 252.4 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"           "num_leaves"
#  [3] "feature_fraction"        "bagging_fraction"
#  [5] "bagging_freq"            "min_data_in_leaf"
#  [7] "lambda_l1"               "lambda_l2"
#  [9] "min_gain_to_split"       "max_depth"
# [11] "min_sum_hessian_in_leaf" "scale_pos_weight"
# [13] "y"                       "dob"
# [15] "eol"                     "error.message"
# [17] "exec.time"               "ei"
# [19] "error.model"             "train.time"
# [21] "prop.type"               "propose.time"
# [23] "se"                      "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate num_leaves feature_fraction bagging_fraction bagging_freq
#            <num>      <int>            <num>            <num>        <int>
# 1:     0.0158797         54        0.6628802        0.9839188            1
#    min_data_in_leaf lambda_l1 lambda_l2 min_gain_to_split max_depth
#               <int>     <num>     <num>             <num>     <int>
# 1:              208  9.793052  4.340608        0.07489479         7
#    min_sum_hessian_in_leaf scale_pos_weight
#                      <num>            <num>
# 1:               0.1216652         11.23722
# [1] 0.9307969

# %% [markdown]
# # Tercer Corrida
#
#
# PARAM$hypeparametertuning$hs <- makeParamSet(
#   makeNumericParam("learning_rate", lower = 0.01, upper = 0.03),
#   makeIntegerParam("num_leaves", lower = 32L, upper = 96L),
#   makeNumericParam("feature_fraction", lower = 0.6, upper = 0.9),
#   makeNumericParam("bagging_fraction", lower = 0.7, upper = 1.0),
#   makeIntegerParam("bagging_freq", lower = 0L, upper = 10L),
#   makeIntegerParam("min_data_in_leaf", lower = 50L, upper = 250L),
#   makeNumericParam("lambda_l1", lower = 0, upper = 10),
#   makeNumericParam("lambda_l2", lower = 0, upper = 10),
#   makeNumericParam("min_gain_to_split", lower = 0, upper = 0.3),
#   makeIntegerParam("max_depth", lower = -1L, upper = 10L),
#   makeNumericParam("min_sum_hessian_in_leaf", lower = 0.0001, upper = 10),
#   makeNumericParam("scale_pos_weight", lower = 10, upper = 200)
# )
#
#
#
# Resultados
#
#     boosting: 'gbdt'
#     objective: 'binary'
#     metric: 'auc'
#     first_metric_only: FALSE
#     boost_from_average: TRUE
#     feature_pre_filter: FALSE
#     force_row_wise: TRUE
#     verbosity: -100
#     seed: 100007
#     max_depth: 7
#     min_gain_to_split: 0.0748947947267801
#     min_sum_hessian_in_leaf: 0.121665196827422
#     lambda_l1: 9.79305189872498
#     lambda_l2: 4.34060802873532
#     max_bin: 31
#     bagging_fraction: 0.983918833499426
#     pos_bagging_fraction: 1
#     neg_bagging_fraction: 1
#     is_unbalance: FALSE
#     scale_pos_weight: 11.2372223031249
#     drop_rate: 0.1
#     max_drop: 50
#     skip_drop: 0.5
#     extra_trees: FALSE
#     num_iterations: 1200
#     learning_rate: 0.0158796965085184
#     feature_fraction: 0.662880188992379
#     num_leaves: 54
#     min_data_in_leaf: 208
#     bagging_freq: 1
#
#
#     Kaggle: 57.997

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100007
#
# $max_depth
# [1] 7
#
# $min_gain_to_split
# [1] 0.07489479
#
# $min_sum_hessian_in_leaf
# [1] 0.1216652
#
# $lambda_l1
# [1] 9.793052
#
# $lambda_l2
# [1] 4.340608
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.9839188
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 11.23722
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.0158797
#
# $feature_fraction
# [1] 0.6628802
#
# $num_leaves
# [1] 54
#
# $min_data_in_leaf
# [1] 208
#
# $bagging_freq
# [1] 1

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Tue Nov 04 12:54:55 AM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
