# %% [markdown]
# <a href="https://colab.research.google.com/github/JaimeLopezGarrido/Trabajos_Labo1/blob/main/src/ensembles/Tarea_05_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# ---
# # Resumen Hiperparametros
#
# LightGBM utiliza el algoritmo de crecimiento de árbol "leaf-wise" (por hoja), mientras que muchas otras herramientas populares utilizan el crecimiento "depth-wise" (por profundidad).
#
# Parámetros Importantes para el Árbol "Leaf-wise":
#
# - *num_leaves*  = Número máximo de hojas que cada árbol puede tener; controla complejidad.
#
#       Este es el parámetro principal para controlar la complejidad del modelo de árbol. Una profundidad no restringida puede inducir el sobreajuste.$num\_leaves = 2^{(max\_depth)}$ para obtener el mismo número de hojas que un árbol "depth-wise".
#
#       - Tiene que ser menor que 2^{(max\_depth)} para evitar overfitting.
#       - Disminuirlo acelera el entrenamiento y reduce overfitting.
#
# - *min_data_in_leaf* = Número mínimo de observaciones que cada hoja debe contener.
#
#       Muy importante para prevenir overfitting, ya que previene hojas con muy pocos datos. Cientos o miles es suficiente para un conjunto de datos grande.
#       - Si sobreajusta hay que subirlo
#       - Si subajusta hay que bajarlo
#
# - *max_depth* = Profundidad máxima de cada árbol; ≤0 significa sin límite. Disminuirlo reduce tiempo y sobreajuste.
#
#       -1 → sin límite (LightGBM lo decide por num_leaves)
#
#       3–8 → árboles pequeños y conservadores
#
#       8–15 → árboles medianos
#
#       > 15 → árboles muy complejos, riesgo de sobreajuste
#
#
#
# ---
# # Arboles, menos profundos, mas rapidos, pero menos precisos.
#
#
# - Disminuir *max_depth*: Reducir la profundidad máxima del árbol para limitar el crecimiento y el tiempo de entrenamiento.
# - Disminuir *num_leaves*: Reducir el número máximo de nodos hoja por árbol, controlando la complejidad y disminuyendo el tiempo de entrenamiento.
# - Aumentar *min_gain_to_split*: Incrementar la ganancia mínima requerida para una división, evitando divisiones de mejora muy pequeña y acortando el entrenamiento.
# - Aumentar *min_data_in_leaf* y *min_sum_hessian_in_leaf*: Aumentar estos valores para prevenir la creación de nodos de árbol muy específicos (sobreajuste) y reducir el tiempo de entrenamiento.
#
# ---
#
# # Entrenar menos árboles
# *num_iterations*
#
# - Número de árboles o rondas de boosting.
#
# - Valores típicos: 500–2000.
#
# - Menos iteraciones → menos tiempo de entrenamiento.
#
# - Si se reduce num_iterations, conviene subir learning_rate (por ejemplo, de 0.03 a 0.1).
#
# *learning_rate*
#
# - Cuánto se ajusta el modelo en cada iteración.
#
# - Valores típicos: 0.01–0.1.
#
# - No afecta el tiempo de entrenamiento, pero sí la precisión.
#
# *early_stopping_round*
#
# - Detiene el entrenamiento si no mejora tras X iteraciones.
#
# - Ejemplo: early_stopping_round = 50.
#
# - Requiere usar un set de validación.
#
# - Permite ahorrar tiempo sin perder rendimiento.
#
# ---
#
# # Menos divisiones por nodo
# *feature_pre_filter*
#
# Si está en TRUE (por defecto), LightGBM filtra variables con poca información antes de entrenar. Mantenerlo en TRUE para acelerar.
#
# *max_bin*
#
# - Cantidad máxima de bins por variable continua.
#
# - Menor valor = entrenamiento más rápido pero menos preciso.
#
# - Valores típicos: 31–255.
#
# - Reducirlo acorta el tiempo de entrenamiento.
#
# *min_data_in_bin*
#
# - Mínimo de datos por bin.
#
# - Aumentarlo reduce el número de bins y acelera el proceso.
#
# - Valor típico: 3–10.
#
# *feature_fraction*
#
# - Porcentaje de variables usadas en cada árbol.
#
# - Ejemplo: feature_fraction = 0.5 usa el 50% de las variables al azar.
#
# - Reducirlo mejora velocidad y ayuda a evitar sobreajuste.
#
# - Valores típicos: 0.5–0.9.
#
# *max_cat_threshold*
#
# - Número máximo de combinaciones evaluadas para variables categóricas.
#
# - Reducirlo disminuye tiempo de cómputo.
#
# - Valores comunes: 16–64.
#
# ---
#
#
# # Usar menos datos por iteración
# *bagging_fraction* y *bagging_freq*
#
# Permiten usar una muestra aleatoria del dataset en cada iteración.
#
# Ejemplo:
#
# - bagging_fraction = 0.75 → usa el 75% de los datos.
#
# - bagging_freq = 5 → cambia la muestra cada 5 iteraciones.
#
# Reducir bagging_fraction acelera el entrenamiento y puede mejorar generalización.
#
# ---
#
# # Para una Mejor Precisión
#
# Para maximizar la precisión del modelo (generalmente a costa de un mayor tiempo de entrenamiento):
#
# - Usar un max_bin grande (puede ser más lento).
#
# - Usar un learning_rate pequeño con un num_iterations grande.
#
# - Usar un num_leaves grande (puede causar sobreajuste).
#
# - Usar datos de entrenamiento más grandes.
#
# - Probar el booster dart.
#
# **Cómo Lidiar con el Sobreajuste**
#
# Para ayudar al modelo a generalizar mejor y evitar el sobreajuste:
#
# - Usar un max_bin pequeño.
#
# - Usar un num_leaves pequeño.
#
# - Usar min_data_in_leaf y min_sum_hessian_in_leaf.
#
# - Usar bagging (agregación de bootstrap) configurando bagging_fraction y bagging_freq.
#
# - Usar submuestreo de características (feature sub-sampling) configurando feature_fraction.
#
# - Usar datos de entrenamiento más grandes.
#
# - Probar lambda_l1, lambda_l2 y min_gain_to_split para regularización.
#
# - Probar max_depth para evitar el crecimiento de árboles profundos.
#
# - Probar el algoritmo extra_trees.
#
# - Probar aumentar path_smooth.

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 02:27:41 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660381 35.3 1454462    77.7 1454462  77.7
# Vcells 1226627  9.4 8388608    64.0 1975128  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()

# %%
PARAM$experimento <- 4
PARAM$semilla_primigenia <- 100007

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
#PARAM$hypeparametertuning$hs <- makeParamSet(
#  makeNumericParam("learning_rate", lower = 0.01, upper = 0.05),
#  makeIntegerParam("num_leaves", lower = 16L, upper = 128L),
#  makeNumericParam("feature_fraction", lower = 0.5, upper = 0.9),
#  makeNumericParam("bagging_fraction", lower = 0.7, upper = 1.0),
#  makeIntegerParam("min_data_in_leaf", lower = 20L, upper = 200L),
#  makeNumericParam("lambda_l1", lower = 0, upper = 10),
#  makeNumericParam("lambda_l2", lower = 0, upper = 10),
#  makeNumericParam("min_gain_to_split", lower = 0, upper = 0.5),
#  makeIntegerParam("max_depth", lower = -1L, upper = 10L)
#)

PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower = 16L, upper = 512L),
  makeIntegerParam("max_depth", lower = 3L, upper = 15L),
  makeNumericParam("learning_rate", lower = 1e-2, upper = 0.3),
  makeIntegerParam("n_estimators", lower = 200L, upper = 3000L),
  makeIntegerParam("min_data_in_leaf", lower = 10L, upper = 200L),
  makeNumericParam("feature_fraction", lower = 0.5, upper = 1.0),
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1.0),
  makeIntegerParam("bagging_freq", lower = 1L, upper = 10L),
  makeNumericParam("lambda_l1", lower = 1e-4, upper = 10.0),
  makeNumericParam("lambda_l2", lower = 1e-4, upper = 10.0),
  makeNumericParam("min_gain_to_split", lower = 0.0, upper = 1.0),
  makeNumericParam("scale_pos_weight", lower = 50, upper = 150)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 35 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83029
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
 modelocv <- lgb.cv(
  data= dtrain,
  nfold= PARAM$hyperparametertuning$xval_folds,
  stratified= TRUE,
  param= param_completo
)

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Nov 03 03:03:57 PM 2025 AUC 0.909532539810231
#
# Mon Nov 03 03:07:31 PM 2025 AUC 0.921799154766002
#
# Mon Nov 03 03:09:35 PM 2025 AUC 0.919574682168755
#
# Mon Nov 03 03:13:50 PM 2025 AUC 0.919253964641665
#
# Mon Nov 03 03:16:57 PM 2025 AUC 0.927627336780844
#
# Mon Nov 03 03:19:24 PM 2025 AUC 0.90143238504341
#
# Mon Nov 03 03:22:24 PM 2025 AUC 0.916929018814496
#
# Mon Nov 03 03:24:39 PM 2025 AUC 0.905022142983919
#
# Mon Nov 03 03:27:33 PM 2025 AUC 0.921449513560722
#
# Mon Nov 03 03:29:29 PM 2025 AUC 0.90356157964467
#
# Mon Nov 03 03:31:53 PM 2025 AUC 0.913971922950486
#
# Mon Nov 03 03:36:13 PM 2025 AUC 0.916220851194246
#
# Mon Nov 03 03:37:52 PM 2025 AUC 0.910608423515439
#
# Mon Nov 03 03:39:49 PM 2025 AUC 0.911542345603073
#
# Mon Nov 03 03:42:05 PM 2025 AUC 0.903560615389034
#
# Mon Nov 03 03:43:57 PM 2025 AUC 0.913565715845656
#
# Mon Nov 03 03:47:57 PM 2025 AUC 0.922743383475866
#
# Mon Nov 03 03:51:39 PM 2025 AUC 0.915343289266232
#
# Mon Nov 03 03:53:40 PM 2025 AUC 0.915681588648357
#
# Mon Nov 03 03:58:10 PM 2025 AUC 0.919417055738371
#
# Mon Nov 03 04:02:24 PM 2025 AUC 0.918683560268465
#
# Mon Nov 03 04:05:12 PM 2025 AUC 0.921206824585417
#
# Mon Nov 03 04:09:53 PM 2025 AUC 0.920511106654376
#
# Mon Nov 03 04:11:43 PM 2025 AUC 0.925298980875258
#
# Mon Nov 03 04:15:40 PM 2025 AUC 0.90325692143583
#
# Mon Nov 03 04:17:46 PM 2025 AUC 0.898077123394827
#
# Mon Nov 03 04:20:38 PM 2025 AUC 0.917714170585094
#
# Mon Nov 03 04:24:29 PM 2025 AUC 0.917829607809661
#
# Mon Nov 03 04:28:49 PM 2025 AUC 0.923371798092065
#
# Mon Nov 03 04:31:27 PM 2025 AUC 0.908205378022176
#
# Mon Nov 03 04:33:52 PM 2025 AUC 0.891711065524567
#
# Mon Nov 03 04:38:20 PM 2025 AUC 0.922376620106297
#
# Mon Nov 03 04:40:26 PM 2025 AUC 0.913809014688075
#
# Mon Nov 03 04:44:40 PM 2025 AUC 0.887729621930421
#
# Mon Nov 03 04:46:45 PM 2025 AUC 0.926597186171717
#
# Mon Nov 03 04:49:21 PM 2025 AUC 0.918848316345478
#
# Mon Nov 03 04:51:54 PM 2025 AUC 0.89183088022312
#
# Mon Nov 03 04:53:29 PM 2025 AUC 0.915474453394873
#
# Mon Nov 03 04:58:39 PM 2025 AUC 0.926965897658666
#
# Mon Nov 03 05:02:10 PM 2025 AUC 0.918105061481592
#
# Mon Nov 03 05:05:08 PM 2025 AUC 0.910291803549085
#
# Mon Nov 03 05:08:25 PM 2025 AUC 0.88584880726686
#
# Mon Nov 03 05:13:30 PM 2025 AUC 0.924242160770921
#
# Mon Nov 03 05:15:46 PM 2025 AUC 0.923008488479735
#
# Mon Nov 03 05:19:16 PM 2025 AUC 0.907612990501749
#
# Mon Nov 03 05:22:11 PM 2025 AUC 0.925508210225528
#
# Mon Nov 03 05:25:20 PM 2025 AUC 0.927648863879553
#
# Mon Nov 03 05:27:03 PM 2025 AUC 0.888360051038143
#
# [mbo] 0: num_leaves=326; max_depth=9; learning_rate=0.198; n_estimators=2384; min_data_in_leaf=115; feature_fraction=0.886; bagging_fraction=0.663; bagging_freq=5; lambda_l1=7.75; lambda_l2=5.27; min_gain_to_split=0.494; scale_pos_weight=105 : y = 0.91 : 124.1 secs : initdesign
#
# [mbo] 0: num_leaves=231; max_depth=10; learning_rate=0.0807; n_estimators=1119; min_data_in_leaf=133; feature_fraction=0.688; bagging_fraction=0.712; bagging_freq=4; lambda_l1=3.96; lambda_l2=3.02; min_gain_to_split=0.623; scale_pos_weight=56.4 : y = 0.922 : 214.1 secs : initdesign
#
# [mbo] 0: num_leaves=240; max_depth=7; learning_rate=0.142; n_estimators=2097; min_data_in_leaf=55; feature_fraction=0.662; bagging_fraction=0.969; bagging_freq=9; lambda_l1=5.37; lambda_l2=4.93; min_gain_to_split=0.521; scale_pos_weight=81.5 : y = 0.92 : 124.2 secs : initdesign
#
# [mbo] 0: num_leaves=399; max_depth=11; learning_rate=0.125; n_estimators=1412; min_data_in_leaf=150; feature_fraction=0.563; bagging_fraction=0.742; bagging_freq=10; lambda_l1=7.68; lambda_l2=3.79; min_gain_to_split=0.125; scale_pos_weight=124 : y = 0.919 : 254.4 secs : initdesign
#
# [mbo] 0: num_leaves=191; max_depth=12; learning_rate=0.0515; n_estimators=1314; min_data_in_leaf=133; feature_fraction=0.624; bagging_fraction=0.976; bagging_freq=7; lambda_l1=5.97; lambda_l2=3.7; min_gain_to_split=0.865; scale_pos_weight=93.4 : y = 0.928 : 187.0 secs : initdesign
#
# [mbo] 0: num_leaves=277; max_depth=14; learning_rate=0.228; n_estimators=2321; min_data_in_leaf=79; feature_fraction=0.65; bagging_fraction=0.757; bagging_freq=2; lambda_l1=3.21; lambda_l2=2.24; min_gain_to_split=0.649; scale_pos_weight=86.8 : y = 0.901 : 147.8 secs : initdesign
#
# [mbo] 0: num_leaves=149; max_depth=13; learning_rate=0.109; n_estimators=1547; min_data_in_leaf=156; feature_fraction=0.85; bagging_fraction=0.524; bagging_freq=8; lambda_l1=8.06; lambda_l2=1.73; min_gain_to_split=0.221; scale_pos_weight=95.6 : y = 0.917 : 179.5 secs : initdesign
#
# [mbo] 0: num_leaves=248; max_depth=11; learning_rate=0.205; n_estimators=610; min_data_in_leaf=85; feature_fraction=0.862; bagging_fraction=0.639; bagging_freq=5; lambda_l1=2.39; lambda_l2=7.42; min_gain_to_split=0.344; scale_pos_weight=111 : y = 0.905 : 134.8 secs : initdesign
#
# [mbo] 0: num_leaves=214; max_depth=5; learning_rate=0.0608; n_estimators=724; min_data_in_leaf=30; feature_fraction=0.806; bagging_fraction=0.848; bagging_freq=9; lambda_l1=3.81; lambda_l2=1.27; min_gain_to_split=0.681; scale_pos_weight=129 : y = 0.921 : 174.0 secs : initdesign
#
# [mbo] 0: num_leaves=423; max_depth=7; learning_rate=0.246; n_estimators=2265; min_data_in_leaf=111; feature_fraction=0.837; bagging_fraction=0.699; bagging_freq=4; lambda_l1=4.7; lambda_l2=4.54; min_gain_to_split=0.83; scale_pos_weight=110 : y = 0.904 : 116.1 secs : initdesign
#
# [mbo] 0: num_leaves=168; max_depth=4; learning_rate=0.24; n_estimators=1514; min_data_in_leaf=128; feature_fraction=0.639; bagging_fraction=0.626; bagging_freq=6; lambda_l1=3.55; lambda_l2=7.28; min_gain_to_split=0.274; scale_pos_weight=54 : y = 0.914 : 144.7 secs : initdesign
#
# [mbo] 0: num_leaves=343; max_depth=9; learning_rate=0.121; n_estimators=1773; min_data_in_leaf=76; feature_fraction=0.512; bagging_fraction=0.595; bagging_freq=4; lambda_l1=9.66; lambda_l2=6.87; min_gain_to_split=0.155; scale_pos_weight=107 : y = 0.916 : 260.1 secs : initdesign
#
# [mbo] 0: num_leaves=394; max_depth=12; learning_rate=0.191; n_estimators=1028; min_data_in_leaf=165; feature_fraction=0.781; bagging_fraction=0.842; bagging_freq=7; lambda_l1=6.09; lambda_l2=1.24; min_gain_to_split=0.71; scale_pos_weight=71.6 : y = 0.911 : 98.0 secs : initdesign
#
# [mbo] 0: num_leaves=296; max_depth=8; learning_rate=0.18; n_estimators=2195; min_data_in_leaf=95; feature_fraction=0.925; bagging_fraction=0.925; bagging_freq=8; lambda_l1=1.32; lambda_l2=1.97; min_gain_to_split=0.392; scale_pos_weight=117 : y = 0.912 : 117.6 secs : initdesign
#
# [mbo] 0: num_leaves=492; max_depth=11; learning_rate=0.262; n_estimators=2675; min_data_in_leaf=161; feature_fraction=0.978; bagging_fraction=0.733; bagging_freq=3; lambda_l1=8.29; lambda_l2=5.79; min_gain_to_split=0.3; scale_pos_weight=149 : y = 0.904 : 135.5 secs : initdesign
#
# [mbo] 0: num_leaves=195; max_depth=14; learning_rate=0.148; n_estimators=2594; min_data_in_leaf=93; feature_fraction=0.788; bagging_fraction=0.691; bagging_freq=9; lambda_l1=2.65; lambda_l2=9.71; min_gain_to_split=0.834; scale_pos_weight=51.9 : y = 0.914 : 112.3 secs : initdesign
#
# [mbo] 0: num_leaves=510; max_depth=7; learning_rate=0.0707; n_estimators=1225; min_data_in_leaf=184; feature_fraction=0.77; bagging_fraction=0.563; bagging_freq=2; lambda_l1=6.93; lambda_l2=7.99; min_gain_to_split=0.0555; scale_pos_weight=130 : y = 0.923 : 240.3 secs : initdesign
#
# [mbo] 0: num_leaves=379; max_depth=4; learning_rate=0.22; n_estimators=340; min_data_in_leaf=70; feature_fraction=0.941; bagging_fraction=0.865; bagging_freq=2; lambda_l1=4.29; lambda_l2=5.07; min_gain_to_split=0.412; scale_pos_weight=121 : y = 0.915 : 222.1 secs : initdesign
#
# [mbo] 0: num_leaves=116; max_depth=6; learning_rate=0.21; n_estimators=1966; min_data_in_leaf=191; feature_fraction=0.822; bagging_fraction=0.822; bagging_freq=6; lambda_l1=1.25; lambda_l2=7.06; min_gain_to_split=0.912; scale_pos_weight=116 : y = 0.916 : 120.4 secs : initdesign
#
# [mbo] 0: num_leaves=35; max_depth=7; learning_rate=0.107; n_estimators=2504; min_data_in_leaf=51; feature_fraction=0.598; bagging_fraction=0.903; bagging_freq=5; lambda_l1=1.49; lambda_l2=4.36; min_gain_to_split=0.0315; scale_pos_weight=90.2 : y = 0.919 : 270.5 secs : initdesign
#
# [mbo] 0: num_leaves=269; max_depth=14; learning_rate=0.117; n_estimators=1279; min_data_in_leaf=62; feature_fraction=0.827; bagging_fraction=0.933; bagging_freq=3; lambda_l1=6.87; lambda_l2=8.41; min_gain_to_split=0.00173; scale_pos_weight=132 : y = 0.919 : 254.1 secs : initdesign
#
# [mbo] 0: num_leaves=108; max_depth=6; learning_rate=0.0448; n_estimators=2011; min_data_in_leaf=26; feature_fraction=0.698; bagging_fraction=0.533; bagging_freq=8; lambda_l1=8.88; lambda_l2=3.49; min_gain_to_split=0.879; scale_pos_weight=104 : y = 0.921 : 167.8 secs : initdesign
#
# [mbo] 0: num_leaves=311; max_depth=7; learning_rate=0.0881; n_estimators=824; min_data_in_leaf=108; feature_fraction=0.532; bagging_fraction=0.808; bagging_freq=9; lambda_l1=1.67; lambda_l2=7.63; min_gain_to_split=0.634; scale_pos_weight=88.6 : y = 0.921 : 280.6 secs : initdesign
#
# [mbo] 0: num_leaves=449; max_depth=3; learning_rate=0.0911; n_estimators=943; min_data_in_leaf=99; feature_fraction=0.735; bagging_fraction=0.616; bagging_freq=8; lambda_l1=9.43; lambda_l2=5.45; min_gain_to_split=0.55; scale_pos_weight=63.1 : y = 0.925 : 110.4 secs : initdesign
#
# [mbo] 0: num_leaves=151; max_depth=15; learning_rate=0.253; n_estimators=872; min_data_in_leaf=120; feature_fraction=0.53; bagging_fraction=0.895; bagging_freq=1; lambda_l1=4.98; lambda_l2=3.31; min_gain_to_split=0.472; scale_pos_weight=140 : y = 0.903 : 237.2 secs : initdesign
#
# [mbo] 0: num_leaves=78; max_depth=11; learning_rate=0.241; n_estimators=2716; min_data_in_leaf=42; feature_fraction=0.743; bagging_fraction=0.557; bagging_freq=4; lambda_l1=5.2; lambda_l2=0.994; min_gain_to_split=0.365; scale_pos_weight=127 : y = 0.898 : 125.8 secs : initdesign
#
# [mbo] 0: num_leaves=348; max_depth=14; learning_rate=0.175; n_estimators=1002; min_data_in_leaf=169; feature_fraction=0.593; bagging_fraction=0.798; bagging_freq=5; lambda_l1=9.1; lambda_l2=9.92; min_gain_to_split=0.954; scale_pos_weight=96.9 : y = 0.918 : 171.8 secs : initdesign
#
# [mbo] 0: num_leaves=286; max_depth=9; learning_rate=0.171; n_estimators=2539; min_data_in_leaf=198; feature_fraction=0.55; bagging_fraction=0.916; bagging_freq=8; lambda_l1=5.83; lambda_l2=2.73; min_gain_to_split=0.168; scale_pos_weight=76.3 : y = 0.918 : 231.1 secs : initdesign
#
# [mbo] 0: num_leaves=261; max_depth=8; learning_rate=0.037; n_estimators=378; min_data_in_leaf=105; feature_fraction=0.954; bagging_fraction=0.778; bagging_freq=5; lambda_l1=2.25; lambda_l2=0.785; min_gain_to_split=0.329; scale_pos_weight=64.6 : y = 0.923 : 260.2 secs : initdesign
#
# [mbo] 0: num_leaves=464; max_depth=10; learning_rate=0.166; n_estimators=2453; min_data_in_leaf=59; feature_fraction=0.909; bagging_fraction=0.508; bagging_freq=6; lambda_l1=4.47; lambda_l2=9.35; min_gain_to_split=0.419; scale_pos_weight=137 : y = 0.908 : 157.6 secs : initdesign
#
# [mbo] 0: num_leaves=202; max_depth=13; learning_rate=0.275; n_estimators=781; min_data_in_leaf=49; feature_fraction=0.985; bagging_fraction=0.764; bagging_freq=3; lambda_l1=7.35; lambda_l2=0.0808; min_gain_to_split=0.598; scale_pos_weight=61.5 : y = 0.892 : 144.9 secs : initdesign
#
# [mbo] 0: num_leaves=472; max_depth=4; learning_rate=0.0663; n_estimators=1134; min_data_in_leaf=25; feature_fraction=0.553; bagging_fraction=0.833; bagging_freq=3; lambda_l1=0.898; lambda_l2=0.233; min_gain_to_split=0.118; scale_pos_weight=120 : y = 0.922 : 268.7 secs : initdesign
#
# [mbo] 0: num_leaves=132; max_depth=4; learning_rate=0.226; n_estimators=264; min_data_in_leaf=86; feature_fraction=0.906; bagging_fraction=0.591; bagging_freq=7; lambda_l1=0.121; lambda_l2=9.54; min_gain_to_split=0.92; scale_pos_weight=67.9 : y = 0.914 : 125.8 secs : initdesign
#
# [mbo] 0: num_leaves=68; max_depth=13; learning_rate=0.297; n_estimators=1835; min_data_in_leaf=123; feature_fraction=0.575; bagging_fraction=0.518; bagging_freq=9; lambda_l1=0.32; lambda_l2=2.32; min_gain_to_split=0.734; scale_pos_weight=100 : y = 0.888 : 254.1 secs : initdesign
#
# [mbo] 0: num_leaves=41; max_depth=3; learning_rate=0.0112; n_estimators=2844; min_data_in_leaf=138; feature_fraction=0.676; bagging_fraction=0.86; bagging_freq=10; lambda_l1=6.46; lambda_l2=8.84; min_gain_to_split=0.507; scale_pos_weight=69.7 : y = 0.927 : 124.5 secs : initdesign
#
# [mbo] 0: num_leaves=318; max_depth=5; learning_rate=0.1; n_estimators=2153; min_data_in_leaf=10; feature_fraction=0.88; bagging_fraction=0.996; bagging_freq=6; lambda_l1=2.94; lambda_l2=5.9; min_gain_to_split=0.781; scale_pos_weight=79 : y = 0.919 : 156.2 secs : initdesign
#
# [mbo] 0: num_leaves=358; max_depth=10; learning_rate=0.284; n_estimators=1710; min_data_in_leaf=66; feature_fraction=0.629; bagging_fraction=0.952; bagging_freq=1; lambda_l1=3.44; lambda_l2=8.67; min_gain_to_split=0.0645; scale_pos_weight=60 : y = 0.892 : 152.8 secs : initdesign
#
# [mbo] 0: num_leaves=127; max_depth=15; learning_rate=0.151; n_estimators=2941; min_data_in_leaf=144; feature_fraction=0.934; bagging_fraction=0.94; bagging_freq=9; lambda_l1=6.34; lambda_l2=2.52; min_gain_to_split=0.975; scale_pos_weight=114 : y = 0.915 : 95.1 secs : initdesign
#
# [mbo] 0: num_leaves=411; max_depth=12; learning_rate=0.03; n_estimators=1823; min_data_in_leaf=187; feature_fraction=0.99; bagging_fraction=0.787; bagging_freq=3; lambda_l1=8.75; lambda_l2=6.56; min_gain_to_split=0.569; scale_pos_weight=56.2 : y = 0.927 : 309.6 secs : initdesign
#
# [mbo] 0: num_leaves=485; max_depth=5; learning_rate=0.159; n_estimators=459; min_data_in_leaf=177; feature_fraction=0.76; bagging_fraction=0.676; bagging_freq=2; lambda_l1=9.29; lambda_l2=0.551; min_gain_to_split=0.804; scale_pos_weight=142 : y = 0.918 : 211.6 secs : initdesign
#
# [mbo] 0: num_leaves=55; max_depth=12; learning_rate=0.196; n_estimators=1927; min_data_in_leaf=195; feature_fraction=0.713; bagging_fraction=0.552; bagging_freq=6; lambda_l1=7.24; lambda_l2=7.71; min_gain_to_split=0.104; scale_pos_weight=141 : y = 0.91 : 178.0 secs : initdesign
#
# [mbo] 0: num_leaves=19; max_depth=8; learning_rate=0.27; n_estimators=532; min_data_in_leaf=14; feature_fraction=0.724; bagging_fraction=0.576; bagging_freq=2; lambda_l1=0.566; lambda_l2=8.29; min_gain_to_split=0.438; scale_pos_weight=147 : y = 0.886 : 197.2 secs : initdesign
#
# [mbo] 0: num_leaves=376; max_depth=15; learning_rate=0.0217; n_estimators=584; min_data_in_leaf=18; feature_fraction=0.867; bagging_fraction=0.647; bagging_freq=7; lambda_l1=5.45; lambda_l2=4.58; min_gain_to_split=0.694; scale_pos_weight=145 : y = 0.924 : 304.4 secs : initdesign
#
# [mbo] 0: num_leaves=454; max_depth=3; learning_rate=0.132; n_estimators=2980; min_data_in_leaf=159; feature_fraction=0.611; bagging_fraction=0.687; bagging_freq=1; lambda_l1=0.706; lambda_l2=6.16; min_gain_to_split=0.768; scale_pos_weight=74.6 : y = 0.923 : 136.4 secs : initdesign
#
# [mbo] 0: num_leaves=180; max_depth=5; learning_rate=0.279; n_estimators=1619; min_data_in_leaf=37; feature_fraction=0.51; bagging_fraction=0.875; bagging_freq=10; lambda_l1=9.9; lambda_l2=1.64; min_gain_to_split=0.98; scale_pos_weight=84.4 : y = 0.908 : 209.8 secs : initdesign
#
# [mbo] 0: num_leaves=67; max_depth=3; learning_rate=0.0251; n_estimators=2800; min_data_in_leaf=40; feature_fraction=0.794; bagging_fraction=0.719; bagging_freq=2; lambda_l1=8.51; lambda_l2=6.42; min_gain_to_split=0.242; scale_pos_weight=134 : y = 0.926 : 175.0 secs : initdesign
#
# [mbo] 0: num_leaves=96; max_depth=15; learning_rate=0.0559; n_estimators=220; min_data_in_leaf=180; feature_fraction=0.679; bagging_fraction=0.985; bagging_freq=1; lambda_l1=1.98; lambda_l2=9.14; min_gain_to_split=0.266; scale_pos_weight=98.6 : y = 0.928 : 188.8 secs : initdesign
#
# [mbo] 0: num_leaves=434; max_depth=9; learning_rate=0.293; n_estimators=1460; min_data_in_leaf=147; feature_fraction=0.96; bagging_fraction=0.614; bagging_freq=10; lambda_l1=2.8; lambda_l2=4.09; min_gain_to_split=0.199; scale_pos_weight=80.1 : y = 0.888 : 103.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:32:51 PM 2025 AUC 0.928773816842604
#
# [mbo] 1: num_leaves=257; max_depth=13; learning_rate=0.0242; n_estimators=801; min_data_in_leaf=185; feature_fraction=0.704; bagging_fraction=0.913; bagging_freq=4; lambda_l1=6.68; lambda_l2=6.49; min_gain_to_split=0.452; scale_pos_weight=102 : y = 0.929 : 346.7 secs : infill_ei
#
# Mon Nov 03 05:35:27 PM 2025 AUC 0.927270131558771
#
# [mbo] 2: num_leaves=202; max_depth=3; learning_rate=0.0458; n_estimators=1732; min_data_in_leaf=185; feature_fraction=0.673; bagging_fraction=0.888; bagging_freq=4; lambda_l1=7.48; lambda_l2=8.19; min_gain_to_split=0.325; scale_pos_weight=70.6 : y = 0.927 : 155.3 secs : infill_ei
#
# Mon Nov 03 05:39:50 PM 2025 AUC 0.927082058751543
#
# [mbo] 3: num_leaves=163; max_depth=15; learning_rate=0.0323; n_estimators=1173; min_data_in_leaf=171; feature_fraction=0.816; bagging_fraction=0.982; bagging_freq=2; lambda_l1=5.44; lambda_l2=5.9; min_gain_to_split=0.74; scale_pos_weight=97.6 : y = 0.927 : 261.0 secs : infill_ei
#
# Saved the current state after iteration 4 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:42:42 PM 2025 AUC 0.928481935217251
#
# [mbo] 4: num_leaves=408; max_depth=14; learning_rate=0.0475; n_estimators=384; min_data_in_leaf=161; feature_fraction=0.752; bagging_fraction=0.989; bagging_freq=6; lambda_l1=7.54; lambda_l2=7.76; min_gain_to_split=0.607; scale_pos_weight=82.7 : y = 0.928 : 171.7 secs : infill_ei
#
# Mon Nov 03 05:46:45 PM 2025 AUC 0.928497324642004
#
# [mbo] 5: num_leaves=131; max_depth=13; learning_rate=0.036; n_estimators=925; min_data_in_leaf=153; feature_fraction=0.631; bagging_fraction=0.989; bagging_freq=7; lambda_l1=8.56; lambda_l2=7.31; min_gain_to_split=0.279; scale_pos_weight=56.5 : y = 0.928 : 241.2 secs : infill_ei
#
# Mon Nov 03 05:51:47 PM 2025 AUC 0.927650610860062
#
# [mbo] 6: num_leaves=385; max_depth=13; learning_rate=0.0342; n_estimators=1294; min_data_in_leaf=168; feature_fraction=0.675; bagging_fraction=0.979; bagging_freq=7; lambda_l1=5.1; lambda_l2=7.2; min_gain_to_split=0.203; scale_pos_weight=79.7 : y = 0.928 : 301.3 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Mon Nov 03 05:55:51 PM 2025 AUC 0.927268231910417
#
# [mbo] 7: num_leaves=208; max_depth=11; learning_rate=0.0332; n_estimators=1256; min_data_in_leaf=185; feature_fraction=0.813; bagging_fraction=0.962; bagging_freq=7; lambda_l1=9.68; lambda_l2=8.11; min_gain_to_split=0.639; scale_pos_weight=84.4 : y = 0.927 : 242.5 secs : infill_ei
#
# Mon Nov 03 06:01:19 PM 2025 AUC 0.926550623718016
#
# [mbo] 8: num_leaves=197; max_depth=14; learning_rate=0.0458; n_estimators=320; min_data_in_leaf=159; feature_fraction=0.567; bagging_fraction=0.96; bagging_freq=5; lambda_l1=7.82; lambda_l2=4.8; min_gain_to_split=0.295; scale_pos_weight=124 : y = 0.927 : 327.2 secs : infill_ei
#
# Mon Nov 03 06:06:49 PM 2025 AUC 0.929052174009692
#
# [mbo] 9: num_leaves=358; max_depth=13; learning_rate=0.0266; n_estimators=573; min_data_in_leaf=138; feature_fraction=0.667; bagging_fraction=0.886; bagging_freq=3; lambda_l1=6.58; lambda_l2=9.26; min_gain_to_split=0.774; scale_pos_weight=58.2 : y = 0.929 : 327.2 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:11:57 PM 2025 AUC 0.928018132883271
#
# [mbo] 10: num_leaves=128; max_depth=13; learning_rate=0.0239; n_estimators=362; min_data_in_leaf=157; feature_fraction=0.712; bagging_fraction=0.871; bagging_freq=6; lambda_l1=5.31; lambda_l2=7.19; min_gain_to_split=0.746; scale_pos_weight=65 : y = 0.928 : 307.0 secs : infill_ei
#
# Mon Nov 03 06:14:04 PM 2025 AUC 0.927555626145927
#
# [mbo] 11: num_leaves=439; max_depth=3; learning_rate=0.023; n_estimators=2622; min_data_in_leaf=140; feature_fraction=0.794; bagging_fraction=0.769; bagging_freq=6; lambda_l1=8.65; lambda_l2=4.4; min_gain_to_split=0.19; scale_pos_weight=58.4 : y = 0.928 : 126.3 secs : infill_ei
#
# Mon Nov 03 06:16:03 PM 2025 AUC 0.925964296814001
#
# [mbo] 12: num_leaves=447; max_depth=4; learning_rate=0.0135; n_estimators=790; min_data_in_leaf=109; feature_fraction=0.779; bagging_fraction=0.831; bagging_freq=1; lambda_l1=8.2; lambda_l2=6.08; min_gain_to_split=0.369; scale_pos_weight=81.3 : y = 0.926 : 118.1 secs : infill_ei
#
# Mon Nov 03 06:20:28 PM 2025 AUC 0.929398106233911
#
# [mbo] 13: num_leaves=357; max_depth=12; learning_rate=0.0229; n_estimators=868; min_data_in_leaf=128; feature_fraction=0.651; bagging_fraction=0.998; bagging_freq=4; lambda_l1=8.35; lambda_l2=5.24; min_gain_to_split=0.538; scale_pos_weight=50.1 : y = 0.929 : 263.4 secs : infill_ei
#
# Saved the current state after iteration 14 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:24:42 PM 2025 AUC 0.926610759136435
#
# [mbo] 14: num_leaves=175; max_depth=4; learning_rate=0.0315; n_estimators=2735; min_data_in_leaf=191; feature_fraction=0.615; bagging_fraction=0.903; bagging_freq=2; lambda_l1=8.35; lambda_l2=4.43; min_gain_to_split=0.468; scale_pos_weight=74.1 : y = 0.927 : 252.5 secs : infill_ei
#
# Mon Nov 03 06:28:05 PM 2025 AUC 0.929057171177442
#
# [mbo] 15: num_leaves=201; max_depth=13; learning_rate=0.0288; n_estimators=554; min_data_in_leaf=109; feature_fraction=0.65; bagging_fraction=0.998; bagging_freq=1; lambda_l1=6.26; lambda_l2=8.1; min_gain_to_split=0.438; scale_pos_weight=75.4 : y = 0.929 : 201.5 secs : infill_ei
#
# Mon Nov 03 06:31:32 PM 2025 AUC 0.927168011755226
#
# [mbo] 16: num_leaves=300; max_depth=13; learning_rate=0.0468; n_estimators=803; min_data_in_leaf=194; feature_fraction=0.642; bagging_fraction=0.963; bagging_freq=1; lambda_l1=8.27; lambda_l2=7.42; min_gain_to_split=0.322; scale_pos_weight=57.8 : y = 0.927 : 205.6 secs : infill_ei
#
# Saved the current state after iteration 17 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:38:06 PM 2025 AUC 0.929419176467802
#
# [mbo] 17: num_leaves=473; max_depth=13; learning_rate=0.0121; n_estimators=1472; min_data_in_leaf=129; feature_fraction=0.644; bagging_fraction=0.94; bagging_freq=5; lambda_l1=9.43; lambda_l2=6.95; min_gain_to_split=0.679; scale_pos_weight=81.4 : y = 0.929 : 392.8 secs : infill_ei
#
# Mon Nov 03 06:44:11 PM 2025 AUC 0.927782621462817
#
# [mbo] 18: num_leaves=411; max_depth=12; learning_rate=0.018; n_estimators=1080; min_data_in_leaf=109; feature_fraction=0.714; bagging_fraction=0.971; bagging_freq=4; lambda_l1=7.17; lambda_l2=6.61; min_gain_to_split=0.57; scale_pos_weight=93.1 : y = 0.928 : 363.7 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Mon Nov 03 06:50:25 PM 2025 AUC 0.929713293389404
#
# [mbo] 19: num_leaves=287; max_depth=14; learning_rate=0.0171; n_estimators=1198; min_data_in_leaf=137; feature_fraction=0.614; bagging_fraction=0.917; bagging_freq=6; lambda_l1=9.47; lambda_l2=7.37; min_gain_to_split=0.589; scale_pos_weight=56.3 : y = 0.93 : 373.1 secs : infill_ei
#
# Mon Nov 03 06:56:38 PM 2025 AUC 0.929115751968667
#
# [mbo] 20: num_leaves=338; max_depth=13; learning_rate=0.0103; n_estimators=1676; min_data_in_leaf=160; feature_fraction=0.71; bagging_fraction=0.951; bagging_freq=6; lambda_l1=9.14; lambda_l2=3.44; min_gain_to_split=0.718; scale_pos_weight=52.2 : y = 0.929 : 370.8 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Mon Nov 03 07:01:50 PM 2025 AUC 0.928882449964635
#
# [mbo] 21: num_leaves=416; max_depth=13; learning_rate=0.0257; n_estimators=1421; min_data_in_leaf=173; feature_fraction=0.596; bagging_fraction=0.825; bagging_freq=9; lambda_l1=9.33; lambda_l2=5.36; min_gain_to_split=0.923; scale_pos_weight=72.3 : y = 0.929 : 311.1 secs : infill_ei
#
# Mon Nov 03 07:07:36 PM 2025 AUC 0.928442012186463
#
# [mbo] 22: num_leaves=349; max_depth=13; learning_rate=0.0227; n_estimators=1758; min_data_in_leaf=157; feature_fraction=0.563; bagging_fraction=0.991; bagging_freq=6; lambda_l1=8.17; lambda_l2=6.7; min_gain_to_split=0.703; scale_pos_weight=63.4 : y = 0.928 : 344.3 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesiana.RDATA.
#
# Mon Nov 03 07:13:15 PM 2025 AUC 0.929207249116743
#
# [mbo] 23: num_leaves=415; max_depth=14; learning_rate=0.0116; n_estimators=257; min_data_in_leaf=142; feature_fraction=0.709; bagging_fraction=0.726; bagging_freq=4; lambda_l1=9.28; lambda_l2=8.68; min_gain_to_split=0.327; scale_pos_weight=74 : y = 0.929 : 337.2 secs : infill_ei
#
# Mon Nov 03 07:18:32 PM 2025 AUC 0.928425748674558
#
# [mbo] 24: num_leaves=489; max_depth=14; learning_rate=0.0217; n_estimators=773; min_data_in_leaf=137; feature_fraction=0.663; bagging_fraction=0.838; bagging_freq=6; lambda_l1=9.71; lambda_l2=4.24; min_gain_to_split=0.622; scale_pos_weight=73.8 : y = 0.928 : 315.5 secs : infill_ei
#
# Saved the current state after iteration 25 in the file bayesiana.RDATA.
#
# Mon Nov 03 07:24:50 PM 2025 AUC 0.929415600839846
#
# [mbo] 25: num_leaves=194; max_depth=13; learning_rate=0.0106; n_estimators=1399; min_data_in_leaf=126; feature_fraction=0.656; bagging_fraction=0.993; bagging_freq=10; lambda_l1=8.61; lambda_l2=5.23; min_gain_to_split=0.492; scale_pos_weight=60.7 : y = 0.929 : 375.9 secs : infill_ei
#
# Mon Nov 03 07:32:17 PM 2025 AUC 0.929698768340477
#
# [mbo] 26: num_leaves=450; max_depth=15; learning_rate=0.0103; n_estimators=236; min_data_in_leaf=157; feature_fraction=0.95; bagging_fraction=0.926; bagging_freq=3; lambda_l1=5.01; lambda_l2=9.86; min_gain_to_split=0.0666; scale_pos_weight=81.2 : y = 0.93 : 445.4 secs : infill_ei
#
# Saved the current state after iteration 27 in the file bayesiana.RDATA.
#
# Mon Nov 03 07:39:16 PM 2025 AUC 0.928424899664058
#
# [mbo] 27: num_leaves=452; max_depth=14; learning_rate=0.01; n_estimators=833; min_data_in_leaf=173; feature_fraction=0.855; bagging_fraction=0.998; bagging_freq=4; lambda_l1=9.09; lambda_l2=9.21; min_gain_to_split=0.367; scale_pos_weight=52 : y = 0.928 : 416.3 secs : infill_ei
#
# Mon Nov 03 07:41:35 PM 2025 AUC 0.925285178986313
#
# [mbo] 28: num_leaves=195; max_depth=3; learning_rate=0.0108; n_estimators=1619; min_data_in_leaf=141; feature_fraction=0.628; bagging_fraction=0.788; bagging_freq=9; lambda_l1=9.59; lambda_l2=4.3; min_gain_to_split=0.0444; scale_pos_weight=101 : y = 0.925 : 136.6 secs : infill_ei
#
# Mon Nov 03 07:49:16 PM 2025 AUC 0.928960105553862
#
# [mbo] 29: num_leaves=401; max_depth=15; learning_rate=0.0104; n_estimators=206; min_data_in_leaf=146; feature_fraction=0.7; bagging_fraction=0.886; bagging_freq=2; lambda_l1=4.06; lambda_l2=9.75; min_gain_to_split=0.0904; scale_pos_weight=92.5 : y = 0.929 : 459.2 secs : infill_ei
#
# Saved the current state after iteration 30 in the file bayesiana.RDATA.
#
# Mon Nov 03 07:56:13 PM 2025 AUC 0.929843010891734
#
# [mbo] 30: num_leaves=179; max_depth=15; learning_rate=0.0107; n_estimators=253; min_data_in_leaf=96; feature_fraction=0.978; bagging_fraction=0.879; bagging_freq=4; lambda_l1=9.07; lambda_l2=7.24; min_gain_to_split=0.396; scale_pos_weight=79.4 : y = 0.93 : 415.2 secs : infill_ei
#
# Mon Nov 03 08:02:30 PM 2025 AUC 0.929713755768301
#
# [mbo] 31: num_leaves=284; max_depth=13; learning_rate=0.0101; n_estimators=266; min_data_in_leaf=129; feature_fraction=0.674; bagging_fraction=0.932; bagging_freq=6; lambda_l1=9.09; lambda_l2=7.26; min_gain_to_split=0.501; scale_pos_weight=78.3 : y = 0.93 : 374.7 secs : infill_ei
#
# Saved the current state after iteration 32 in the file bayesiana.RDATA.
#
# Mon Nov 03 08:09:45 PM 2025 AUC 0.929075512658928
#
# [mbo] 32: num_leaves=271; max_depth=15; learning_rate=0.011; n_estimators=339; min_data_in_leaf=135; feature_fraction=0.857; bagging_fraction=0.942; bagging_freq=3; lambda_l1=7.08; lambda_l2=7.32; min_gain_to_split=0.377; scale_pos_weight=73.7 : y = 0.929 : 434.1 secs : infill_ei
#
# Mon Nov 03 08:16:00 PM 2025 AUC 0.927493955139067
#
# [mbo] 33: num_leaves=372; max_depth=15; learning_rate=0.0138; n_estimators=407; min_data_in_leaf=173; feature_fraction=0.996; bagging_fraction=0.759; bagging_freq=3; lambda_l1=3.94; lambda_l2=10; min_gain_to_split=0.254; scale_pos_weight=122 : y = 0.927 : 373.1 secs : infill_ei
#
# Saved the current state after iteration 34 in the file bayesiana.RDATA.
#
# Mon Nov 03 08:22:29 PM 2025 AUC 0.927428584958107
#
# [mbo] 34: num_leaves=244; max_depth=14; learning_rate=0.0224; n_estimators=201; min_data_in_leaf=78; feature_fraction=0.998; bagging_fraction=0.881; bagging_freq=5; lambda_l1=4.96; lambda_l2=9.49; min_gain_to_split=0.129; scale_pos_weight=65.6 : y = 0.927 : 387.6 secs : infill_ei
#
# Mon Nov 03 08:29:12 PM 2025 AUC 0.929561576194232
#
# [mbo] 35: num_leaves=220; max_depth=15; learning_rate=0.0103; n_estimators=576; min_data_in_leaf=117; feature_fraction=0.66; bagging_fraction=0.87; bagging_freq=3; lambda_l1=9.99; lambda_l2=9.21; min_gain_to_split=0.994; scale_pos_weight=137 : y = 0.93 : 401.2 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_leaves"        "max_depth"         "learning_rate"
#  [4] "n_estimators"      "min_data_in_leaf"  "feature_fraction"
#  [7] "bagging_fraction"  "bagging_freq"      "lambda_l1"
# [10] "lambda_l2"         "min_gain_to_split" "scale_pos_weight"
# [13] "y"                 "dob"               "eol"
# [16] "error.message"     "exec.time"         "ei"
# [19] "error.model"       "train.time"        "prop.type"
# [22] "propose.time"      "se"                "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_leaves max_depth learning_rate n_estimators min_data_in_leaf
#         <int>     <int>         <num>        <int>            <int>
# 1:        179        15    0.01071297          253               96
#    feature_fraction bagging_fraction bagging_freq lambda_l1 lambda_l2
#               <num>            <num>        <int>     <num>     <num>
# 1:        0.9778362         0.879424            4  9.074415  7.236361
#    min_gain_to_split scale_pos_weight
#                <num>            <num>
# 1:          0.395588         79.35603
# [1] 0.929843

# %% [markdown]
# # Cuarta Corrida: "GPT" Profesor
#
# Pruebo corrida de chat con chat gpt que paso el profesor por Zulip
#
# PARAM$hypeparametertuning$hs <- makeParamSet(
#   makeIntegerParam("num_leaves", lower = 16L, upper = 512L),
#   makeIntegerParam("max_depth", lower = 3L, upper = 15L),
#   makeNumericParam("learning_rate", lower = 1e-2, upper = 0.3),
#   makeIntegerParam("n_estimators", lower = 200L, upper = 3000L),
#   makeIntegerParam("min_data_in_leaf", lower = 10L, upper = 200L),
#   makeNumericParam("feature_fraction", lower = 0.5, upper = 1.0),
#   makeNumericParam("bagging_fraction", lower = 0.5, upper = 1.0),
#   makeIntegerParam("bagging_freq", lower = 1L, upper = 10L),
#   makeNumericParam("lambda_l1", lower = 1e-4, upper = 10.0),
#   makeNumericParam("lambda_l2", lower = 1e-4, upper = 10.0),
#   makeNumericParam("min_gain_to_split", lower = 0.0, upper = 1.0),
#   makeNumericParam("scale_pos_weight", lower = 50, upper = 150),
#   makeDiscreteParam("boosting_type", values = c("gbdt", "dart"))
# )
#
#     boosting: 'gbdt'
#     objective: 'binary'
#     metric: 'auc'
#     first_metric_only: FALSE
#     boost_from_average: TRUE
#     feature_pre_filter: FALSE
#     force_row_wise: TRUE
#     verbosity: -100
#     seed: 100007
#     max_depth: 15
#     min_gain_to_split: 0.39558796
#     min_sum_hessian_in_leaf: 0.001
#     lambda_l1: 9.0744155
#     lambda_l2: 7.2363611
#     max_bin: 31
#     bagging_fraction: 0.879424
#     pos_bagging_fraction: 1
#     neg_bagging_fraction: 1
#     is_unbalance: FALSE
#     scale_pos_weight: 79.35603169
#     drop_rate: 0.1
#     max_drop: 50
#     skip_drop: 0.5
#     extra_trees: FALSE
#     num_iterations: 1200
#     learning_rate: 0.01071297
#     feature_fraction: 0.9778362
#     num_leaves: 179
#     min_data_in_leaf: 96
#     n_estimators: 253
#     bagging_freq: 4
#
#     Kaggle: 57.407

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 100007
#
# $max_depth
# [1] 15
#
# $min_gain_to_split
# [1] 0.395588
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 9.074415
#
# $lambda_l2
# [1] 7.236361
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.879424
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 79.35603
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1200
#
# $learning_rate
# [1] 0.01071297
#
# $feature_fraction
# [1] 0.9778362
#
# $num_leaves
# [1] 179
#
# $min_data_in_leaf
# [1] 96
#
# $n_estimators
# [1] 253
#
# $bagging_freq
# [1] 4

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}
# Out:
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr
# Successfully submitted to LaboI 2025 virtual analista sr

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Nov 03 08:37:46 PM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
